# %%
import os
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_dir = os.path.join('PMLSdata','01HIVseries')
file_name = 'HIVseries.csv'
file = os.path.join(data_dir, file_name)

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
t = np.linspace(0, 1, 101)
plt.figure()
# plt.subplot(2, 2, 1); 
# plt.hist(np.random.random(20)) # Upper left 
plt.subplot(2, 2, 2); 
plt.plot(t, t**2, t, t**3 - t) # Upper right
# plt.subplot(2, 2, 3); plt.plot(random(20), random(20), 'r*') # Lower left 
plt.subplot(2, 2, 4);
plt.plot(t*np.cos(10*t), t*np.sin(10*t))
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
fig = plt.figure()
ax = Axes3D(fig)
t = np.linspace(0, 5*np.pi, 501)
# Create a new figure.
# Create 3D plotter attached to figure.
# Define parameter for parametric plot.
ax.plot(np.cos(t),np.sin(t), t)
# ax.view_init(elev=30,azim=30)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
fig = plt.figure()
ax = Axes3D(fig)
t = np.linspace(0, 5*np.pi, 501)
# Create a new figure.
# Create 3D plotter attached to figure.
# Define parameter for parametric plot.
ax.plot(np.cos(t),np.sin(t), t)
ax.view_init(elev=10,azim=30)

# %%
# %matplotlib notebook

# %%
x = np.linspace(0,11,100)
y = np.random.rand(100)
z = np.random.rand(100)
plt.plot(x, y, 'r')
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
plt.plot(x, z)

# %%
my_file = open('power.txt', 'w')
print( " N \t\t2**N\t\t3**N" ) # Print labels for columns.
print( "---\t\t----\t\t----" ) # Print separator. my_file.write( " N \t\t2**N\t\t3**N\n" )# Write labels to file.
my_file.write( "---\t\t----\t\t----\n" )# Write separator to file. #%% Loop over integers from 0 to 10 and print/write results.
for N in range(11):
    print( "{:d}\t\t{:d}\t\t{:d}".format(N, pow(2,N), pow(3,N)) ) 
    my_file.write( "{:d}\t\t{:d}\t\t{:d}\n".format(N, pow(2,N), pow(3,N)) )
my_file.close()
# Out:
#  N 		2**N		3**N
# ---		----		----
# 0		1		1
# 1		2		3
# 2		4		9
# 3		8		27
# 4		16		81
# 5		32		243
# 6		64		729
# 7		128		2187
# 8		256		6561
# 9		512		19683
# 10		1024		59049

# %%
# %cat power.txt
# Out:
# ---		----		----
# 0		1		1
# 1		2		3
# 2		4		9
# 3		8		27
# 4		16		81
# 5		32		243
# 6		64		729
# 7		128		2187
# 8		256		6561
# 9		512		19683
# 10		1024		59049

# %%
url =  "http://www.physics.upenn.edu/biophys/PMLS/Datasets/01HIVseries/HIVseries.csv"
r = requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
np.array(r.text)
# Out:
# array('0, 1.061e+05\n0.0831, 93240\n0.1465, 1.6672e+05\n0.2587, 1.5378e+05\n0.4828, 1.188e+05\n0.7448, 1.169e+05\n0.9817, 1.0957e+05\n1.2563, 1.1135e+05\n1.4926, 74388\n1.7299, 83291\n1.9915, 66435\n3.0011, 35408\n4.0109, 21125\n5.009, 20450\n5.9943, 15798\n7.0028, 4785.2\n',
#       dtype='<U251')

# %%
with open(file) as infile:
    print(type(infile))
    print(infile)
    temp = []
    for line in infile:
        x, y = line.split(',')
        temp.append((float(x), float(y)))
# Out:
# <class '_io.TextIOWrapper'>
# <_io.TextIOWrapper name='PMLSdata/01HIVseries/HIVseries.csv' mode='r' encoding='UTF-8'>

# %%
temp
# Out:
# [(0.0, 106100.0),
#  (0.0831, 93240.0),
#  (0.1465, 166720.0),
#  (0.2587, 153780.0),
#  (0.4828, 118800.0),
#  (0.7448, 116900.0),
#  (0.9817, 109570.0),
#  (1.2563, 111350.0),
#  (1.4926, 74388.0),
#  (1.7299, 83291.0),
#  (1.9915, 66435.0),
#  (3.0011, 35408.0),
#  (4.0109, 21125.0),
#  (5.009, 20450.0),
#  (5.9943, 15798.0),
#  (7.0028, 4785.2)]

# %%
np.array(temp)
# Out:
# array([[0.0000e+00, 1.0610e+05],
#        [8.3100e-02, 9.3240e+04],
#        [1.4650e-01, 1.6672e+05],
#        [2.5870e-01, 1.5378e+05],
#        [4.8280e-01, 1.1880e+05],
#        [7.4480e-01, 1.1690e+05],
#        [9.8170e-01, 1.0957e+05],
#        [1.2563e+00, 1.1135e+05],
#        [1.4926e+00, 7.4388e+04],
#        [1.7299e+00, 8.3291e+04],
#        [1.9915e+00, 6.6435e+04],
#        [3.0011e+00, 3.5408e+04],
#        [4.0109e+00, 2.1125e+04],
#        [5.0090e+00, 2.0450e+04],
#        [5.9943e+00, 1.5798e+04],
#        [7.0028e+00, 4.7852e+03]])

# %%
# %cat PMLSdata/01HIVseries/README.txt
# Out:
# HIV infection time course.
#
# File HIVseries.mat contains a single variable "a" with two columns of data.  The
# first is the time in days since administration of a treatment to an HIV positive
# patient; the second contains the concentration of virus in that patient's blood,
# in arbitrary units.
#
# HIVseries.csv and HIVseries.npy contain the same data in the same format.
# HIVseries.npz contains the same data in two separate arrays called
# 'time_in_days' and 'viral_load'.
#
# Data from A. Perelson. Modelling viral and immune system dynamics. Nature Revs.
# Immunol. (2002) vol. 2 (1) pp. 28--36 (Box 1).

# %%
# %cat PMLSdata/01HIVseries/HIVseries.csv
# Out:
# 0, 1.061e+05
# 0.0831, 93240
# 0.1465, 1.6672e+05
# 0.2587, 1.5378e+05
# 0.4828, 1.188e+05
# 0.7448, 1.169e+05
# 0.9817, 1.0957e+05
# 1.2563, 1.1135e+05
# 1.4926, 74388
# 1.7299, 83291
# 1.9915, 66435
# 3.0011, 35408
# 4.0109, 21125
# 5.009, 20450
# 5.9943, 15798
# 7.0028, 4785.2

# %%
f1 = np.loadtxt(file, delimiter = ',')
f1
# Out:
# array([[0.0000e+00, 1.0610e+05],
#        [8.3100e-02, 9.3240e+04],
#        [1.4650e-01, 1.6672e+05],
#        [2.5870e-01, 1.5378e+05],
#        [4.8280e-01, 1.1880e+05],
#        [7.4480e-01, 1.1690e+05],
#        [9.8170e-01, 1.0957e+05],
#        [1.2563e+00, 1.1135e+05],
#        [1.4926e+00, 7.4388e+04],
#        [1.7299e+00, 8.3291e+04],
#        [1.9915e+00, 6.6435e+04],
#        [3.0011e+00, 3.5408e+04],
#        [4.0109e+00, 2.1125e+04],
#        [5.0090e+00, 2.0450e+04],
#        [5.9943e+00, 1.5798e+04],
#        [7.0028e+00, 4.7852e+03]])
