# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-np.pi, np.pi, 256, endpoint = True)
C, S = np.sin(x), np.cos(x)

# %%
plt.figure(figsize = (10,6), dpi=80)
plt.plot(x, S, label = 'sin(x)', linewidth = 2.5)
plt.plot(x, C, label = 'cos(x)', linewidth = 2.5)
plt.xlim(x.min() * 1.1, x.max() * 1.1)
plt.ylim(S.min() * 1.1, S.max() * 1.1)
# plt.xticks(np.linspace(-4,4,9, endpoint = True))
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi], [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$\pi/2$', r'$\pi$'])
plt.yticks(np.linspace(-1,1,2, endpoint = True))

ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
# ax.spines['right'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))

t = 2 * np.pi / 3
plt.plot([t,t], [0, np.cos(t)], color='tab:blue', linestyle='--')
# plt.plot(t, np.cos(t), 'o', color = 'tab:blue')
plt.scatter([t,], [np.cos(t),], 50, color='tab:blue')

for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize(16)
    label.set_bbox(dict(facecolor='white', alpha=0.3))

plt.legend(loc='upper left', frameon = False);

# %%
for label in ax.get_xticklabels() + ax.get_yticklabels():
    print(label)
# for x, y, label in ax.get_xticklabels(), ax.get_yticklabels(), ax.get_xticklabels() + ax.get_yticklabels():
#     print(x)
#     print(y)
#     print(label)
#     print('---')
# Out:
# Text(-3.141592653589793, 0, '$-\\pi$')
# Text(-1.5707963267948966, 0, '$-\\pi/2$')
# Text(0.0, 0, '$0$')
# Text(1.5707963267948966, 0, '$\\pi/2$')
# Text(3.141592653589793, 0, '$\\pi$')
# Text(0, -1.0, '−1')
# Text(0, 1.0, '1')

# %%
### plt.figure(figsize = (10,6))
plt.plot(x, S, label = 'sin(x)', linewidth = 2.5)
plt.plot(x, C, label = 'cos(x)', linewidth = 2.5)
# plt.xlim(x.min() * 1.1, x.max() * 1.1)
plt.legend();
